# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('data/reference/lopucki_brd_2023.csv', encoding='latin-1', on_bad_lines='skip')
df.head()
# Out:
#                                NameCorp  \
# 0                1st Centennial Bancorp
# 1  21st Century Oncology Holdings, Inc.
# 2            A. H. Robins Company, Inc.
# 3                    A. M. Castle & Co.
# 4                    A123 Systems, Inc.
#
#                                        AfterEmerging  Assets1Before  \
# 0                                                NaN            NaN
# 1                                                NaN            NaN
# 2   Became a unit of American Home Products 12/15/89        648.000
# 3                                                NaN        329.328
# 4  assets acquired by Wanxiang America Corporatio...        625.902
#
#    Assets2Before  Assets3Before  AssetsBefore  AssetsCurrDollar  \
# 0        690.000            NaN       690.000               963
# 1       1128.244            NaN      1128.244              1368
# 2        509.663        439.983       648.000              1781
# ...

# %%
df['CikEmerging'].value_counts()
# Out:
# CikEmerging
# 1282648.0    2
# 906469.0     2
# 19411.0      2
# 943320.0     2
# 850660.0     2
#             ..
# 1467858.0    1
# 1443799.0    1
# 1496048.0    1
# 771934.0     1
# 109265.0     1
# Name: count, Length: 358, dtype: int64

# %%
df.info(verbose=True, show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1218 entries, 0 to 1217
# Data columns (total 217 columns):
#  #    Column                 Non-Null Count  Dtype
# ---   ------                 --------------  -----
#  0    NameCorp               1218 non-null   object
#  1    AfterEmerging          549 non-null    object
#  2    Assets1Before          913 non-null    float64
#  3    Assets2Before          546 non-null    float64
#  4    Assets3Before          318 non-null    float64
#  5    AssetsBefore           1218 non-null   float64
#  6    AssetsCurrDollar       1218 non-null   int64
#  7    AssetsEmerging         429 non-null    float64
#  8    AssetsPetCurrDollar    883 non-null    float64
#  9    AssetsPetition         883 non-null    float64
#  10   BondISIN               217 non-null    object
#  11   BondPriceDisp          161 non-null    float64
#  12   BondPriceFile          161 non-null    float64
#  13   BondPriceMoveDuring    151 non-null    float64
# ...

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)

# %%
df.select_dtypes(include=['object']).info(verbose=True, show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1218 entries, 0 to 1217
# Data columns (total 125 columns):
#  #    Column                 Non-Null Count  Dtype
# ---   ------                 --------------  -----
#  0    NameCorp               1218 non-null   object
#  1    AfterEmerging          549 non-null    object
#  2    BondISIN               217 non-null    object
#  3    CaseNum                1218 non-null   object
#  4    CaseNumRefile          173 non-null    object
#  5    CaseNumTransfer        28 non-null     object
#  6    CeoFiling              1218 non-null   object
#  7    CeoNotes               412 non-null    object
#  8    CeoReplaced            1218 non-null   object
#  9    Chapter                1218 non-null   object
#  10   CityChange             44 non-null     object
#  11   CityDisposed           1169 non-null   object
#  12   CityFiled              1218 non-null   object
#  13   CityFiledCategory      1218 non-null   object
# ...

# %%
df.select_dtypes(include=['object']).head(20)
# Out:
#                                 NameCorp  \
# 0                 1st Centennial Bancorp
# 1   21st Century Oncology Holdings, Inc.
# 2             A. H. Robins Company, Inc.
# 3                     A. M. Castle & Co.
# 4                     A123 Systems, Inc.
# 5                     AAC Holdings, Inc.
# 6                         aaiPharma Inc.
# 7                         ABC-NACO, Inc.
# 8                    AbitibiBowater Inc.
# 9    Acceptance Insurance Companies Inc.
# 10                  Accuride Corporation
# 11                     Aceto Corporation
# 12             Acme Metals, Incorporated
# 13               ACT Manufacturing, Inc.
# 14                         Acterna Corp.
# 15     Adelphia Business Solutions, Inc.
# 16         Adelphia Communications Corp.
# 17                   Adeptus Health Inc.
# 18         Advanced GlassFiber Yarns LLC
# 19          Advanced Radio Telecom Corp.
#
# ...
